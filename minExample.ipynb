# %% [markdown]
# # Extract and Parse
#
# This notebook
#
# Download an annual report, Extract a particular note to financial statements, Parse it into .md format

# %%
# NEED???
# !pip install llama-index

# !pip install llama-index-core llama-parse 
#!pip install llama-index-readers-file #python-dotenv
# Out:
# Collecting llama-index
#   Downloading llama_index-0.12.9-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.1-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-cli<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_cli-0.4.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.13.0,>=0.12.9 (from llama-index)
#   Downloading llama_index_core-0.12.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-embeddings-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.6.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-llms-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.3.12-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.4.2-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4.0,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-file<0.5.0,>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_file-0.4.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting nltk>3.8.1 (from llama-index)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index)
#   Downloading openai-1.58.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (6.0.2)
# Collecting SQLAlchemy>=1.4.49 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading SQLAlchemy-2.0.36-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading aiohttp-3.11.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting dataclasses-json (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2024.2.0)
# Requirement already satisfied: httpx in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (3.2.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (11.0.0)
# Collecting pydantic>=2.8.0 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading pydantic-2.10.4-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests>=2.31.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (9.0.0)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading tiktoken-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm<5.0.0,>=4.66.1 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.9->llama-index) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wrapt (from llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading wrapt-1.17.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting llama-cloud>=0.1.5 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.7-py3-none-any.whl.metadata (860 bytes)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.12.3)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.3)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index)
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.5.19-py3-none-any.whl.metadata (7.0 kB)
# Collecting click (from nltk>3.8.1->llama-index)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk>3.8.1->llama-index)
#   Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.6)
# Requirement already satisfied: certifi<2025.0.0,>=2024.7.4 in /home/codespace/.local/lib/python3.12/site-packages (from llama-cloud>=0.1.5->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2024.8.30)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (1.0.7)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.9->llama-index) (0.14.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index)
#   Downloading jiter-0.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.3.1)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.9->llama-index) (2.2.3)
# Collecting greenlet!=0.4.17 (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.13.0,>=0.12.9->llama-index)
#   Downloading marshmallow-3.23.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.9->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.17.0)
# Downloading llama_index-0.12.9-py3-none-any.whl (6.8 kB)
# Downloading llama_index_agent_openai-0.4.1-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.4.0-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.12.9-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.0 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.6.3-py3-none-any.whl (11 kB)
# Downloading llama_index_llms_openai-0.3.12-py3-none-any.whl (14 kB)
# Downloading llama_index_multi_modal_llms_openai-0.4.2-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.4.1-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.1 MB/s eta 0:00:00
# Downloading aiohttp-3.11.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.8 MB/s eta 0:00:00
# Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading llama_cloud-0.1.7-py3-none-any.whl (242 kB)
# Downloading llama_parse-0.5.19-py3-none-any.whl (15 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading openai-1.58.1-py3-none-any.whl (454 kB)
# Downloading pydantic-2.10.4-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 46.0 MB/s eta 0:00:00
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
# Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 34.7 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 53.7 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tiktoken-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.3 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading wrapt-1.17.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 25.8 MB/s eta 0:00:00
# Downloading jiter-0.8.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Downloading marshmallow-3.23.2-py3-none-any.whl (49 kB)
# Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
# Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
# Installing collected packages: striprtf, filetype, dirtyjson, wrapt, tqdm, regex, pypdf, pydantic-core, propcache, mypy-extensions, multidict, marshmallow, jiter, greenlet, frozenlist, distro, click, annotated-types, aiohappyeyeballs, yarl, typing-inspect, tiktoken, SQLAlchemy, pydantic, nltk, deprecated, aiosignal, openai, llama-cloud, dataclasses-json, aiohttp, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiosignal-1.3.2 annotated-types-0.7.0 click-8.1.8 dataclasses-json-0.6.7 deprecated-1.2.15 dirtyjson-1.0.8 distro-1.9.0 filetype-1.2.0 frozenlist-1.5.0 greenlet-3.1.1 jiter-0.8.2 llama-cloud-0.1.7 llama-index-0.12.9 llama-index-agent-openai-0.4.1 llama-index-cli-0.4.0 llama-index-core-0.12.9 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.6.3 llama-index-llms-openai-0.3.12 llama-index-multi-modal-llms-openai-0.4.2 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.1 llama-index-readers-llama-parse-0.4.0 llama-parse-0.5.19 marshmallow-3.23.2 multidict-6.1.0 mypy-extensions-1.0.0 nltk-3.9.1 openai-1.58.1 propcache-0.2.1 pydantic-2.10.4 pydantic-core-2.27.2 pypdf-5.1.0 regex-2024.11.6 striprtf-0.0.26 tiktoken-0.8.0 tqdm-4.67.1 typing-inspect-0.9.0 wrapt-1.17.0 yarl-1.18.3
# Requirement already satisfied: llama-index-core in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.12.9)
# Requirement already satisfied: llama-parse in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.5.19)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (3.11.11)
# Requirement already satisfied: dataclasses-json in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (2024.2.0)
# Requirement already satisfied: httpx in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (11.0.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-index-core) (1.17.0)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from llama-parse) (8.1.8)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.18.3)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from dataclasses-json->llama-index-core) (3.23.2)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx->llama-index-core) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx->llama-index-core) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx->llama-index-core) (1.3.1)

# %%
import os

# Access the secrets from environment variables
os.environ["LLAMA_CLOUD_API_KEY"] = os.getenv('LLAMA_CLOUD_API_KEY')

# Display environment variables (for debugging purposes)
#print(os.environ.get('LLAMA_CLOUD_API_KEY'))

# %%
# bring in deps
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader

# set up parser
parser = LlamaParse(#api_key="llx-...", # put your LlamaParse api key here
    premium_mode=True,  #Accurate_mode is the default
    parsing_instruction = "The provided pdf document is extracted from the Notes to financial statements in a company annual report. The document contains tables (with financial amounts) and texts from a note on segment reporting. Each page of the pdf document has a footer (with the company name and the year of the report, followed by the page number) and a header (with the section name of the company annual report). Some tables may have table footnotes that are numbered. The table footnotes explain details about certain items in the table that are tagged with superscript numbers. Please convert the pdf document into a markdown document with an equivalent page formatting as similar to the original pdf document as possible. Make sure you convert heading to heading and paragraph to paragraph with exact words and table to table with exact structure of rows and columns.",
    is_formatting_instruction=True,
    disable_ocr=False,#True,
    skip_diagonal_text=True,
    do_not_unroll_columns=False, # unroll columns 
    #target_pages="0,2,7",  # Pages are numbered starting at 0
    bounding_box="0.08,0,0.08,0",
    take_screenshot=True,
    disable_image_extraction=True,
    result_type="markdown"  # "markdown" and "text" are available
)


# Needed for nested loop?
import nest_asyncio
nest_asyncio.apply()

# %%
documents = parser.load_data("./docs4Parsing/abstract.pdf")

print(documents[0].text[0000:7000])
# Out:
# Started parsing the file under job_id b2b9725b-1568-4492-b74f-93a863183120
# # Investigating the Impact of Religion
# # Regarding Internal Control in Nonprofit Organizations
#
# ## Abstract
#
# This dissertation first synthesizes existing research on the intersection between religion and two key economic behaviors: financial risk-taking and financial reporting. It then empirically examines how the degree of religiosity of the geographical area surrounding the nonprofit organization – or of the country in which it is located – influences either the likelihood or the number of internal control deficiencies (ICDs) reported by the organization.
#
# The first chapter of the dissertation provides a structured review of selected studies on religion's influence, regarding financial risk-taking and financial reporting. The main insight from these studies is that religion promotes positive economic behaviors, such as ethical financial practices and reduced risk-taking, rooted in its moral guidelines and conservative ethos. Despite this, some research finds negative outcomes associated with religion under certain circumstances. Thus, the context can shift religion's influence on economic behaviors. To facilitate future research, a conceptual model is proposed, highlighting interactions between religion and individuals, organizations, and their respective behaviors. This framework aims to support further exploration into how religious social norms influence economic behaviors in different contexts.
#
# Focusing on nonprofit organizations, the second chapter examines whether the likelihood of ICDs is associated with religiosity. Using U.S. data and factor analysis to develop a religiosity score, this study finds that the higher the degree of religiosity in the geographic area surrounding a nonprofit organization, the more prone the organization is to ICDs. This risk is moderated by organizational size, which aligns with the notion that larger organizations have more resources to establish robust internal controls. My findings highlight the potential

# %%
documents = parser.load_data("./docs4Parsing/PwC2024_segment.pdf")

print(documents[0].text[0000:7000])
#print(documents)
# Out:
# Started parsing the file under job_id 1c435c9b-ab11-4c96-832d-dabbb2354880
# The image appears to be entirely blank or white. There is no visible content, text, or graphics present in this image. It seems to be an empty white canvas or background without any discernible features or information.

# %%
file_extractor = {".pdf": parser}
documents = SimpleDirectoryReader(
    "./docs4Parsing", file_extractor=file_extractor
).load_data()

# %%
# use SimpleDirectoryReader to parse our file
file_extractor = {".pdf": parser}
#documents = SimpleDirectoryReader(input_files=['data/canada.pdf'], file_extractor=file_extractor).load_data()
documents = SimpleDirectoryReader(input_files=['docs4Parsing/PwC2024_segment.pdf'], file_extractor=file_extractor).load_data()
#documents = SimpleDirectoryReader(input_files=['docs4Parsing/Nextplc2008_segment.pdf'], file_extractor=file_extractor).load_data()
